# %%
from sklearn.cluster import KMeans
from sklearn.datasets._samples_generator import make_blobs
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# %%
X, y = make_blobs(n_samples=500, centers=4, cluster_std=0.60, random_state=0)

X.shape, y.shape
# Out:
# ((500, 2), (500,))

# %%
plt.scatter(X[:, 0], X[:, 1], s=50)

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
y_pred = kmeans.predict(X)

plt.scatter(X[:, 0], X[:, 1], c=y_pred, s=50, cmap='viridis')
# Out:
# c:\Users\dldls\anaconda3\envs\study3-2\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

# %%
    print("K", kmeans.inertia_)
# Out:
# K 4743.706736868626
# K 1969.599499370272
# K 895.541402385528
# K 345.1797115465465
# K 310.4424652980359
# K 279.47418001627057
# K 251.02099187761473
# K 224.26509091407456
# K 203.5979811783169
# K 184.46593469327829
# K 165.91398479657212
# K 149.19778326383724
# K 139.45451103493144
# K 130.97908908991258
# K 121.8582464356307
# K 113.38428961967838
# K 107.8902822666821
# K 101.8680288860355
# K 98.11711772388227

# %%
inertia_arr = []

for k in range(1, 20):
    kmeans = KMeans(n_clusters=k, random_state=200)
    kmeans.fit(X)
    inertia_arr.append(kmeans.inertia_)

plt.plot(range(1, 20), inertia_arr)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %%
# K 값은 3.75 정도가 적당한 것으로 볼 수 있다.

# %%
# K 값은 3.75 정도가 적당한 것으로 볼 수 있다.
